# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# # Bar Graph

# %%
num_1 = ['A','B','C','D','E']
num_2 = [3,4,3,2,2]

plt.bar(num_1, num_2)
plt.show()

# %%
x = [3,4,9,3,2,3,2]
y = [2,1,2,2,6,5,1]

plt.scatter(x,y)
plt.show()
